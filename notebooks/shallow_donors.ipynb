# %%
from wand.image import Image as WImage
from wand.display import display
img = WImage(filename='/home/dominique/BTSync/SolidState/Brno/SemiCon/Humlicek/TA_Notes/Donor_States_III_V/1-s2.0-S1350449599000201-main.pdf[3]', resolution=400)
print img.size
print img.format
img.resize(2*595L, 2*842L)
print img.size
img
#converted = img.convert('jpeg')
#converted
# Out:
# (3306L, 4678L)
# PDF
# (1190L, 1684L)
# <wand.image.Image: 072fa5b 'PDF' (1190x1684)>

# %%
import scipy.constants as cst
import math

# %%
r = 0.067 * (1.0/12.5)**2 * (cst.e**4*cst.m_e/(2.0*cst.hbar**2))*(1.0/(4.0*math.pi*cst.epsilon_0)**2)

# %%
r/cst.e*1000.0
# Out:
# 5.8341209654160515

# %%
cst.epsilon_0
# Out:
# 8.854187817620389e-12

# %%
cst.physical_constants["Rydberg constant"][0]
# Out:
# 10973731.568539

# %%
cst.physical_constants["Rydberg constant"][1]
# Out:
# 'm^-1'

# %%
cst.e**4*cst.m_e/(2.0*cst.hbar**2)
# Out:
# 2.698660275393679e-38
