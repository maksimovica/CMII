# %%
# %matplotlib inline

# %% [markdown]
# # Si

# %%
import pickle
import numpy as np
from ase.lattice import bulk
from gpaw import GPAW, PW, FermiDirac
from ase.dft.kpoints import ibz_points, get_bandpath

# Perform standard ground state calculation (with plane wave basis)
si = bulk('Si', 'diamond', 5.43)
calc = GPAW(mode=PW(200),
            xc='PBE',
            kpts=(8, 8, 8),
            occupations=FermiDirac(0.01),
            txt='Si_gs.txt')
si.set_calculator(calc)
si.get_potential_energy()
calc.write('Si_gs.gpw')

# %%
# Restart from ground state and obtain Fermi level
calc = GPAW('Si_gs.gpw',
            txt=None,
            fixdensity=True,
            eigensolver='cg',
            usesymm=None,
            convergence={'bands': 7})
ef = calc.get_fermi_level()

# Use ase.dft module for obtaining k-points along high symmetry directions
points = ibz_points['fcc']
G = points['Gamma']
X = points['X']
W = points['W']
K = points['K']
L = points['L']
kpts, x, X = get_bandpath([W, L, G, X, W, K], calc.atoms.cell)
calc.set(kpts=kpts)
calc.get_potential_energy()
e_kn = np.array([calc.get_eigenvalues(k) for k in range(len(kpts))])
e_kn -= ef

# %%
# Plot the band structure
#import matplotlib
#matplotlib.use('Agg')
#matplotlib.rc('text', usetex=True)
import matplotlib.pyplot as plt

point_names = ['W', 'L', '\Gamma', 'X', 'W', 'K']

emin = e_kn.min() - 1
emax = e_kn[:,7].max() + 1

plt.figure(figsize=(12, 8))
for n in range(7):
    plt.plot(x, e_kn[:, n], 'b')
for p in X:
    plt.plot([p, p], [emin, emax], 'k-')
plt.plot([0, X[-1]], [0, 0], 'k-')
plt.xticks(X, [r'$%s$' % n for n in point_names])
plt.axis(xmin=0, xmax=X[-1], ymin=emin, ymax=emax)
plt.xlabel('k-vector')
plt.ylabel(r'E - $E_F$ (eV)')
plt.title('Bandstructure of Silicon')
plt.show()
plt.savefig('bandstructure.pdf')

# %% [markdown]
# # Ge

# %%
# Perform standard ground state calculation (with plane wave basis)
si = bulk('Ge', 'diamond', 5.64)
calc = GPAW(mode=PW(200),
            xc='PBE',
            kpts=(8, 8, 8),
            occupations=FermiDirac(0.01),
            txt='Ge_gs.txt')
si.set_calculator(calc)
si.get_potential_energy()
calc.write('Ge_gs.gpw')

# %%
# Restart from ground state and obtain Fermi level
calc = GPAW('Ge_gs.gpw',
            txt=None,
            fixdensity=True,
            eigensolver='cg',
            usesymm=None,
            convergence={'bands': 'occupied'})
ef = calc.get_fermi_level()

# Use ase.dft module for obtaining k-points along high symmetry directions
points = ibz_points['fcc']
G = points['Gamma']
X = points['X']
W = points['W']
K = points['K']
L = points['L']
kpts, x, X = get_bandpath([W, L, G, X, W, K], calc.atoms.cell)
calc.set(kpts=kpts)
calc.get_potential_energy()
e_kn = np.array([calc.get_eigenvalues(k) for k in range(len(kpts))])
e_kn -= ef

# %%
# Plot the band structure
point_names = ['W', 'L', '\Gamma', 'X', 'W', 'K']

emin = e_kn.min() - 1
emax = e_kn[:,7].max() + 1

plt.figure(figsize=(12, 8))
for n in range(7):
    plt.plot(x, e_kn[:, n], 'b')
for p in X:
    plt.plot([p, p], [emin, emax], 'k-')
plt.plot([0, X[-1]], [0, 0], 'k-')
plt.xticks(X, [r'$%s$' % n for n in point_names])
plt.axis(xmin=0, xmax=X[-1], ymin=emin, ymax=emax)
plt.xlabel('k-vector')
plt.ylabel(r'E - $E_F$ (eV)')
plt.title('Bandstructure of Ge')
plt.savefig('Ge_bandstructure.pdf')

# %% [markdown]
# # Sn

# %%
# Perform standard ground state calculation (with plane wave basis)
si = bulk('Sn', 'diamond', 6.48)
calc = GPAW(mode=PW(200),
            xc='PBE',
            kpts=(8, 8, 8),
            occupations=FermiDirac(0.01),
            txt='Sn_gs.txt')
si.set_calculator(calc)
si.get_potential_energy()
calc.write('Sn_gs.gpw')

# %%
# Restart from ground state and obtain Fermi level
calc = GPAW('Sn_gs.gpw',
            txt=None,
            fixdensity=True,
            eigensolver='cg',
            usesymm=None,
            convergence={'bands': 'occupied'})
ef = calc.get_fermi_level()

# Use ase.dft module for obtaining k-points along high symmetry directions
points = ibz_points['fcc']
G = points['Gamma']
X = points['X']
W = points['W']
K = points['K']
L = points['L']
kpts, x, X = get_bandpath([W, L, G, X, W, K], calc.atoms.cell)
calc.set(kpts=kpts)
calc.get_potential_energy()
e_kn = np.array([calc.get_eigenvalues(k) for k in range(len(kpts))])
e_kn -= ef

# %%
# Plot the band structure
point_names = ['W', 'L', '\Gamma', 'X', 'W', 'K']
taille = e_kn.shape[1]
emin = e_kn.min() - 1
emin = -12
emax = e_kn[:,:].max() + 1

plt.figure(figsize=(12, 8))
for n in range(taille):
    plt.plot(x, e_kn[:, n], 'b')
for p in X:
    plt.plot([p, p], [emin, emax], 'k-')
plt.plot([0, X[-1]], [0, 0], 'k-')
plt.xticks(X, [r'$%s$' % n for n in point_names])
plt.axis(xmin=0, xmax=X[-1], ymin=emin, ymax=emax)
plt.xlabel('k-vector')
plt.ylabel(r'E - $E_F$ (eV)')
plt.title('Bandstructure of Sn')
plt.savefig('Sn_bandstructure.pdf')

# %% [markdown]
# # Na

# %%
from gpaw import GPAW, FermiDirac
from ase import Atoms

a = 4.23
atoms = Atoms('Na2',
              scaled_positions=[[0, 0, 0], [.5, .5, .5]],
              cell=(a, a, a),
              pbc=True)

# Make self-consistent calculation and save results
calc = GPAW(h=0.25,
            kpts=(8, 8, 8),
            occupations=FermiDirac(width=0.05),
            nbands=5,
            setups={'Na': '1'},
            txt='Na_sc.txt')

atoms.set_calculator(calc)
atoms.get_potential_energy()
calc.write('Na_sc.gpw')

# Calculate band structure along Gamma-X i.e. from 0 to 0.5
#nkpt = 40
#kpts = [(0.5 * k / (nkpt - 1), 0, 0) for k in range(nkpt)]

calc = GPAW('Na_sc.gpw',
            txt='Na_harris.txt',
            kpts=(8, 8, 8),
            fixdensity=True,
            nbands=5,
            parallel={'domain': 1},
            usesymm=None,
            eigensolver='cg',
            convergence={'bands': 5})

if calc.input_parameters['mode'] == 'lcao':
    calc.scf.reset()

calc.get_potential_energy()
calc.write('Na_harris.gpw')

# %%
from gpaw import GPAW
from pylab import *
from ase.dft.kpoints import ibz_points, get_bandpath

calc = GPAW('Na_harris.gpw', txt=None)
nbands = calc.get_number_of_bands()
kpts = calc.get_ibz_k_points()
nkpts = len(kpts)



# Use ase.dft module for obtaining k-points along high symmetry directions
points = ibz_points['bcc']
G = points['Gamma']
P = points['P']
H = points['H']
N = points['N']
kpts, x, X = get_bandpath([G, H, N, P, G, N], calc.atoms.cell)
calc.set(kpts=kpts)
calc.get_potential_energy()
ef = calc.get_fermi_level()
e_kn = np.array([calc.get_eigenvalues(k) for k in range(len(kpts))])
e_kn -= ef

# %%
# Plot the band structure
#matplotlib.rc('text', usetex=True)

point_names = ['\Gamma','H', 'N', 'P', '\Gamma', 'N']

taille = e_kn.shape[1]
emin = e_kn.min() - 1
emax = e_kn[:,:].max() + 1

plt.figure(figsize=(12, 8))
for n in range(taille):
    plt.plot(x, e_kn[:, n], 'b')
for p in X:
    plt.plot([p, p], [emin, emax], 'k-')
plt.plot([0, X[-1]], [0, 0], 'k-')
plt.xticks(X, [r'$%s$' % n for n in point_names])
plt.axis(xmin=0, xmax=X[-1], ymin=emin, ymax=emax)
plt.xlabel('k-vector')
plt.ylabel(r'E - E$_F$ (eV)')
plt.title('Bandstructure of Na')
plt.savefig('Na_bandstructure.pdf')

# %% [markdown]
# # Na v2

# %%
# Perform standard ground state calculation (with plane wave basis)
from ase.lattice import bulk

si = bulk('Na', 'bcc', 4.23)


calc = GPAW(mode='fd',
            xc='LDA',
            nbands = 8,
            kpts=(8, 8, 8),
            occupations=FermiDirac(0.1),
            gpts=(24, 24, 24),
            txt='Na_gs.txt')


si.set_calculator(calc)
si.get_potential_energy()
calc.write('Na_gs.gpw')
# Out:
# ---------------------------------------------------------------------------
# KohnShamConvergenceError                  Traceback (most recent call last)
# <ipython-input-27-84f6e42f022c> in <module>()
#      15
#      16 si.set_calculator(calc)
# ---> 17 si.get_potential_energy()
#      18 calc.write('Na_gs.gpw')
#
# /usr/lib/python2.7/dist-packages/ase/atoms.pyc in get_potential_energy(self)
#     546         if self._calc is None:
#     547             raise RuntimeError('Atoms object has no calculator.')
# --> 548         return self._calc.get_potential_energy(self)
#     549
#     550     def get_potential_energies(self):
#
# /home/dominique/gpaw/gpaw/aseinterface.pyc in get_potential_energy(self, atoms, force_consistent)
#      35             atoms = self.atoms
#      36
# ---> 37         self.calculate(atoms, converge=True)
#      38
#      39         if force_consistent:
#
# /home/dominique/gpaw/gpaw/paw.pyc in calculate(self, atoms, converge, force_call_to_set_positions)
#     279             if 'not_converged' in hooks:
#     280                 hooks['not_converged'](self)
# --> 281             raise KohnShamConvergenceError('Did not converge!')
#     282
#     283     def initialize_positions(self, atoms=None):
#
# KohnShamConvergenceError: Did not converge!

# %%
# Perform standard ground state calculation (with plane wave basis)
si = bulk('Na', 'bcc', 4.23)


calc = GPAW(mode='fd',
            xc='LDA',
            nbands = 6,
            kpts=(8, 8, 8),
            occupations=FermiDirac(0.1),
            gpts=(24, 24, 24),
            txt='Na_gs.txt')


si.set_calculator(calc)
si.get_potential_energy()
calc.write('Na_gs.gpw')

# %%
# Restart from ground state and obtain Fermi level
calc = GPAW('Na_gs.gpw',
            txt=None,
            fixdensity=True,
            eigensolver='cg',
            usesymm=None,
            convergence={'bands': 6})
ef = calc.get_fermi_level()

# Use ase.dft module for obtaining k-points along high symmetry directions
points = ibz_points['bcc']
G = points['Gamma']
P = points['P']
H = points['H']
N = points['N']
kpts, x, X = get_bandpath([G, N, P, H, G, P, H, N], calc.atoms.cell)
calc.set(kpts=kpts)
calc.get_potential_energy()
e_kn = np.array([calc.get_eigenvalues(k) for k in range(len(kpts))])
e_kn -= ef

# %%
# Plot the band structure
#matplotlib.rc('text', usetex=True)

point_names = ['\Gamma','N', 'P', 'H', '\Gamma', 'P', 'H', 'N']


emin = e_kn.min() - 1
emax = e_kn[:,6].max() + 1

plt.figure(figsize=(12, 8))
for n in range(6):
    plt.plot(x, e_kn[:, n], 'b')
for p in X:
    plt.plot([p, p], [emin, emax], 'k-')
plt.plot([0, X[-1]], [0, 0], 'k-')
plt.xticks(X, [r'$%s$' % n for n in point_names])
plt.axis(xmin=0, xmax=X[-1], ymin=emin, ymax=emax)
plt.xlabel('k-vector')
plt.ylabel(r'E - E$_F$ (eV)')
plt.title('Bandstructure of Na')
plt.savefig('Na_bandstructure.pdf')

# %% [markdown]
# # Na v3

# %%
from gpaw import GPAW, FermiDirac
from ase import Atoms

a = 4.23
atoms = Atoms('Na2',
              scaled_positions=[[0, 0, 0], [.5, .5, .5]],
              cell=(a, a, a),
              pbc=True)

# Make self-consistent calculation and save results
calc = GPAW(h=0.25,
            kpts=(8, 8, 8),
            occupations=FermiDirac(width=0.05),
            nbands=3,
            setups={'Na': '1'},
            txt='Na_sc.txt')

atoms.set_calculator(calc)
atoms.get_potential_energy()
calc.write('Na_sc.gpw')

# Calculate band structure along Gamma-X i.e. from 0 to 0.5
nkpt = 40
kpts = [(0.5 * k / (nkpt - 1), 0, 0) for k in range(nkpt)]

calc = GPAW('Na_sc.gpw',
            txt='Na_harris.txt',
            kpts=kpts,
            fixdensity=True,
            nbands=7,
            parallel={'domain': 1},
            usesymm=None,
            eigensolver='cg',
            convergence={'bands': 'all'})

if calc.input_parameters['mode'] == 'lcao':
    calc.scf.reset()

calc.get_potential_energy()
calc.write('Na_harris.gpw')

# %%
from gpaw import GPAW
from pylab import *

calc = GPAW('Na_harris.gpw', txt=None)
nbands = calc.get_number_of_bands()
kpts = calc.get_ibz_k_points()
nkpts = len(kpts)

eigs = empty((nbands, nkpts), float)

for k in range(nkpts):
    eigs[:, k] = calc.get_eigenvalues(kpt=k)

# Subtract Fermi level from the self-consistent calculation
eigs -= GPAW('Na_sc.gpw', txt=None).get_fermi_level()
for n in range(nbands):
    plot(kpts[:, 0], eigs[n], '.m')
show()

# %% [markdown]
# # DOS

# %%
import sys
import pylab
from gpaw import GPAW
import matplotlib.pyplot as plt

calc = GPAW('Si_gs.gpw', txt=None)
try:
    ef = calc.get_fermi_level()
except ValueError:
    ef = 0
energy, dos = calc.get_dos(spin=0, width=0.05)


plt.figure(figsize=(12, 8))
plt.axis(xmin=-15, xmax=6, ymin=0, ymax=1.6)
plt.xlabel(r'$\epsilon - \epsilon_F \ \rm{(eV)}$')
plt.ylabel('Density of States (1/eV)')
plt.title('Si - Density of states - theory')

plt.plot(energy - ef, dos, label='up, down', ls='-', lw=2)
if calc.get_number_of_spins() == 2:
    energy, dos = calc.get_dos(spin=1, width=width)
    plt.plot(energy - ef, dos, label='up, down', ls='-', lw=2)
    
#plt.legend(loc=2)
plt.savefig('Si_DOS.pdf')
